# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
import matplotlib.dates as mdates

SH_df = pd.read_excel('./000001.SZ.xlsx')
Iflytek_df = pd.read_excel('./002030.SZ.xlsx')
VisualChina_df = pd.read_excel('./000681.SZ.xlsx')
Moutai_df = pd.read_excel('./600519.SH.xlsx')
CITIC_df = pd.read_excel('./600300.SH.xlsx')

# %%
from datetime import datetime
df_dict = {"PingAnBank": SH_df, "Iflytek": Iflytek_df, "VisualChina": VisualChina_df, "Moutai": Moutai_df, "CITIC": CITIC_df}
n = 1
for name,df in df_dict.items():
    df = df.iloc[::-1]# sequentially
    df['trade_date'] = df['trade_date'].apply(lambda x:datetime.strptime(str(x),"%Y%m%d"))
    df['trade_date']=pd.to_datetime(df['trade_date'])
    df.info()
    sns.set()
    warnings.filterwarnings('ignore')
    plt.figure(figsize=(24, 14), dpi=100, num=4)
    # volume chart
    x = df['trade_date']
    y1 = df['vol']
    plt.plot(x, y1, color='r', label='volume nums', linewidth=2)
    plt.xlabel('trade_date', fontsize=10)
    plt.ylabel('volume', fontsize=10)
    plt.title('volume chart for '+name, fontsize=15)
    print('volume chart')
    plt.savefig(f'figure{n}.jpg')
    plt.show()
    n += 1
    # OHLC chart
    plt.figure(figsize=(24, 14), dpi=100, num=4)
    x = df['trade_date']
    plt.plot(x, df.loc[:, 'open'], label='open price', linewidth=2)
    plt.plot(x, df.loc[:, 'high'], label='high price', linewidth=2)
    plt.plot(x, df.loc[:, 'low'], label='low price', linewidth=2)
    plt.plot(x, df.loc[:, 'close'], label='close price', linewidth=2)
    plt.xlabel('date', fontsize=15)
    plt.ylabel('price/exchange', fontsize=15)
    plt.title('OHLC chart', fontsize=15)
    print('OHLC chart')
    plt.savefig(f'figure{n}.jpg')
    plt.show()
    n += 1
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 4999 to 0
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  5000 non-null   int64
#  1   ts_code     5000 non-null   object
#  2   trade_date  5000 non-null   datetime64[ns]
#  3   open        5000 non-null   float64
#  4   high        5000 non-null   float64
#  5   low         5000 non-null   float64
#  6   close       5000 non-null   float64
#  7   pre_close   5000 non-null   float64
#  8   change      5000 non-null   float64
#  9   pct_chg     5000 non-null   float64
#  10  vol         5000 non-null   float64
#  11  amount      5000 non-null   float64
# dtypes: datetime64[ns](1), float64(9), int64(1), object(1)
# memory usage: 468.9+ KB
# volume chart
# OHLC chart
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3638 entries, 3637 to 0
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  3638 non-null   int64
#  1   ts_code     3638 non-null   object
#  2   trade_date  3638 non-null   datetime64[ns]
#  3   open        3638 non-null   float64
#  4   high        3638 non-null   float64
#  5   low         3638 non-null   float64
#  6   close       3638 non-null   float64
#  7   pre_close   3638 non-null   float64
#  8   change      3638 non-null   float64
#  9   pct_chg     3638 non-null   float64
#  10  vol         3638 non-null   float64
#  11  amount      3638 non-null   float64
# dtypes: datetime64[ns](1), float64(9), int64(1), object(1)
# memory usage: 341.2+ KB
# volume chart
# OHLC chart
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4236 entries, 4235 to 0
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  4236 non-null   int64
#  1   ts_code     4236 non-null   object
#  2   trade_date  4236 non-null   datetime64[ns]
#  3   open        4236 non-null   float64
#  4   high        4236 non-null   float64
#  5   low         4236 non-null   float64
#  6   close       4236 non-null   float64
#  7   pre_close   4236 non-null   float64
#  8   change      4236 non-null   float64
#  9   pct_chg     4236 non-null   float64
#  10  vol         4236 non-null   float64
#  11  amount      4236 non-null   float64
# dtypes: datetime64[ns](1), float64(9), int64(1), object(1)
# memory usage: 397.3+ KB
# volume chart
# OHLC chart
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4379 entries, 4378 to 0
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  4379 non-null   int64
#  1   ts_code     4379 non-null   object
#  2   trade_date  4379 non-null   datetime64[ns]
#  3   open        4379 non-null   float64
#  4   high        4379 non-null   float64
#  5   low         4379 non-null   float64
#  6   close       4379 non-null   float64
#  7   pre_close   4379 non-null   float64
#  8   change      4379 non-null   float64
#  9   pct_chg     4379 non-null   float64
#  10  vol         4379 non-null   float64
#  11  amount      4379 non-null   float64
# dtypes: datetime64[ns](1), float64(9), int64(1), object(1)
# memory usage: 410.7+ KB
# volume chart
# OHLC chart
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4640 entries, 4639 to 0
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  4640 non-null   int64
#  1   ts_code     4640 non-null   object
#  2   trade_date  4640 non-null   datetime64[ns]
#  3   open        4640 non-null   float64
#  4   high        4640 non-null   float64
#  5   low         4640 non-null   float64
#  6   close       4640 non-null   float64
#  7   pre_close   4640 non-null   float64
#  8   change      4640 non-null   float64
#  9   pct_chg     4640 non-null   float64
#  10  vol         4640 non-null   float64
#  11  amount      4640 non-null   float64
# dtypes: datetime64[ns](1), float64(9), int64(1), object(1)
# memory usage: 435.1+ KB
# volume chart
# OHLC chart
